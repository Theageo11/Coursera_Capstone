# %%
import numpy as np
import pandas as pd
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# this notebook will be mainly used for the capstone project

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
df.head()
# Out:
#   Postal code           Borough                Neighborhood
# 0         M1A      Not assigned                         NaN
# 1         M2A      Not assigned                         NaN
# 2         M3A        North York                   Parkwoods
# 3         M4A        North York            Victoria Village
# 4         M5A  Downtown Toronto  Regent Park / Harbourfront

# %%
drop_col=df[df['Borough']=='Not assigned'].index
df=df.drop(drop_col,inplace=False)
df.head(20)
# Out:
#    Postal code           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# 8          M9A         Etobicoke
# 9          M1B       Scarborough
# 11         M3B        North York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M6B        North York
# 17         M9B         Etobicoke
# 18         M1C       Scarborough
# 20         M3C        North York
# 21         M4C         East York
# 22         M5C  Downtown Toronto
# 23         M6C              York
# 26         M9C         Etobicoke
# 27         M1E       Scarborough
# 30         M4E      East Toronto
#
#                                          Neighborhood
# 2                                           Parkwoods
# 3                                    Victoria Village
# 4                          Regent Park / Harbourfront
# 5                   Lawrence Manor / Lawrence Heights
# 6        Queen's Park / Ontario Provincial Government
# 8                                    Islington Avenue
# 9                                     Malvern / Rouge
# 11                                          Don Mills
# 12                   Parkview Hill / Woodbine Gardens
# 13                           Garden District, Ryerson
# 14                                          Glencairn
# 17  West Deane Park / Princess Gardens / Martin Gr...
# 18           Rouge Hill / Port Union / Highland Creek
# 20                                          Don Mills
# 21                                   Woodbine Heights
# 22                                     St. James Town
# 23                                 Humewood-Cedarvale
# 26  Eringate / Bloordale Gardens / Old Burnhamthor...
# 27                Guildwood / Morningside / West Hill
# 30                                        The Beaches

# %%
df.reset_index(drop=True)
df.head()
# Out:
#   Postal code           Borough                                  Neighborhood
# 2         M3A        North York                                     Parkwoods
# 3         M4A        North York                              Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park / Harbourfront
# 5         M6A        North York             Lawrence Manor / Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government

# %%
import sys
# !{sys.executable} -m pip install geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
# Requirement already satisfied: click in c:\users\zhy92\anaconda3\lib\site-packages (from geocoder) (7.0)
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: requests in c:\users\zhy92\anaconda3\lib\site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: future in c:\users\zhy92\anaconda3\lib\site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: six in c:\users\zhy92\anaconda3\lib\site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: decorator in c:\users\zhy92\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\zhy92\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zhy92\anaconda3\lib\site-packages (from requests->geocoder) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\zhy92\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\zhy92\anaconda3\lib\site-packages (from requests->geocoder) (1.24.2)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
import geocoder 

def get_location(postal_code):
    lat_lng_coords = None

    
    while(lat_lng_coords is None):
      g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
      lat_lng_coords = g.latlng

    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    return latitude, longitude


for x in df['Postal code']:
    print(get_location(x))

# %%
geo_df=pd.read_csv('http://cocl.us/Geospatial_data')
geo_df
