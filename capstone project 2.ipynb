# %%
import numpy as np
import pandas as pd
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# this notebook will be mainly used for the capstone project

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
df.head()
# Out:
#   Postal code           Borough                Neighborhood
# 0         M1A      Not assigned                         NaN
# 1         M2A      Not assigned                         NaN
# 2         M3A        North York                   Parkwoods
# 3         M4A        North York            Victoria Village
# 4         M5A  Downtown Toronto  Regent Park / Harbourfront

# %%
drop_col=df[df['Borough']=='Not assigned'].index
df=df.drop(drop_col,inplace=False)
df
# Out:
#     Postal code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# 5                    Lawrence Manor / Lawrence Heights
# 6         Queen's Park / Ontario Provincial Government
# ..                                                 ...
# 160    The Kingsway / Montgomery Road / Old Mill North
# 165                               Church and Wellesley
# 168              Business reply mail Processing CentrE
# 169  Old Mill South / King's Mill Park / Sunnylea /...
# 178  Mimico NW / The Queensway West / South of Bloo...
#
# [103 rows x 3 columns]

# %%
df.reset_index(drop=True)
df.rename(columns={'Postal code':'Postalcode'},inplace=True)
df.head()
# Out:
#   Postalcode           Borough                                  Neighborhood
# 2        M3A        North York                                     Parkwoods
# 3        M4A        North York                              Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park / Harbourfront
# 5        M6A        North York             Lawrence Manor / Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government

# %%
import sys
# !{sys.executable} -m pip install geocoder
# Out:
# Requirement already satisfied: geocoder in c:\users\zhy92\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: requests in c:\users\zhy92\anaconda3\lib\site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: future in c:\users\zhy92\anaconda3\lib\site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: six in c:\users\zhy92\anaconda3\lib\site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: ratelim in c:\users\zhy92\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: click in c:\users\zhy92\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\zhy92\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\zhy92\anaconda3\lib\site-packages (from requests->geocoder) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\zhy92\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zhy92\anaconda3\lib\site-packages (from requests->geocoder) (2019.9.11)
# Requirement already satisfied: decorator in c:\users\zhy92\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.0)

# %%
geo_df=pd.read_csv('http://cocl.us/Geospatial_data')
geo_df
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
geo_df.rename(columns={'Postal Code':'Postalcode'},inplace=True)
df= pd.merge(geo_df, df, on='Postalcode')

# %%
geo_data=df[['Postalcode','Borough','Neighborhood','Latitude','Longitude']]

# %%
geo_data
# Out:
#     Postalcode      Borough  \
# 0          M1B  Scarborough
# 1          M1C  Scarborough
# 2          M1E  Scarborough
# 3          M1G  Scarborough
# 4          M1H  Scarborough
# ..         ...          ...
# 98         M9N         York
# 99         M9P    Etobicoke
# 100        M9R    Etobicoke
# 101        M9V    Etobicoke
# 102        M9W    Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                      Malvern / Rouge  43.806686 -79.194353
# 1             Rouge Hill / Port Union / Highland Creek  43.784535 -79.160497
# 2                  Guildwood / Morningside / West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village / St. Phillips / Martin Grov...  43.688905 -79.554724
# 101  South Steeles / Silverstone / Humbergate / Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]
